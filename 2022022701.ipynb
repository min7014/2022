# %% [markdown]
# <a href="https://colab.research.google.com/github/min7014/2022/blob/main/2022022701.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 밀양여고 정보부

# %% [markdown]
#  ## 컴퓨터 이름과 그룹 바꾸기

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 키보드에서

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# windows 키를 누른 상태에서 바로 E 키를 누룹니다,

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 파일 탐색기 창이 나타납니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 마우스로 내 PC를 선택함.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 마우스 오른쪽 버튼을 클릭.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 새로 메뉴가 나타남.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 새로 나타난 메뉴에서 속성을 선택합니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 설정창이 나타납니다.
#
# 이 PC의 이름 바꾸기(고급)를 선택합니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 시스템 속성창이 나타납니다.
#
# 컴퓨터 설명에 홍길동 이라 입렵합니다.
#
# 변경버튼을 누릅니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 컴퓨터 이름/도메인 변경창이 나타납니다.
#
# 컴퓨터 이름에 홍길동 이라 입렵합니다.
#
# 작업 그룹에 밀양여고 라 입력합니다.
#
# 확인을 선택합니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 컴퓨터 이름/도메인 변경 팝업창이 나타납니다.
#
# 밀양여고 작업 그룹 시작 메시지가 나타납니다.
#
# 확인을 선택합니다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 컴퓨터 이름/도메인 변경 팝업창이 나타납니다.
#
# 변경 내용 적용 ... 이란 메시지가 나타납니다.
#
# 확인을 선택합니다.
