# %% [markdown]
# <a href="https://colab.research.google.com/github/min7014/2022/blob/main/2022071401.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 단말기 기본세팅

# %% [markdown]
# ## 단말기 등록

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 웨일 실행

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# [네이버 웨일 로그인] 선택

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 1. 학교/기관 로그인 선택후 잠시 기다리면 whalespace 가 나타남.
#
# 2. 아이톡톡 아이디 와 암호 입력
#
# 3. 계정 저장하기 체크박스 선택
#
# 4. 로그인 선택
#
# <참고>
#
# 아이디(1학년): 2022571***@gne.go.kr
#
# 아이디(2학년): 2021571***@gne.go.kr
#
# 초기암호 : 1234
#
# ***은 자신의 고유번호임
#
# 비밀번호를 잊은 경우는 별표시 화살표에 비밀번호 찾기를 통하여 찾을 수 있음.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 창닫기 선택

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 1. 상단에 있는 주소창 옆에 홈모양(집모양)을 선택하여 경남 이이톡톡 뉴탭 으로 이동
#
#   경우에 따라서는 아래와 같이 뉴탭에 대한 동의를 구 할 수 있다.
#
# 2. [학생 단말기등록] 선택

# %% [markdown]
# ***  아래의 내용은 처음 홈탭을 선택했을 때 나타나는 화면이다. 동의하고 나서 위의 그림이 나타나면 [학생단말기등록]을 선택

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# [동의하기] 선택한다.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 경상남도교육청 학생용 스마트단말기 등록 페이지에가 나타나면 아래로 이동하여 동의를 선택

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 1. 인증코드 숫자를 선택
#
# 2. 인증코드 "******"가 클립보드에 복사 되었다는 메시지의 [확인] 버튼 선택
#
# 3. [단말기 등록 프로그램 다운로드] 선택

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# [열기] 버튼 선택

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 추가정보를 선택

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# [실행] 선택

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 1. 하단에 빨간색의 단말기 인증 프로그램이 실행 됩니다. 선택하여 맨 앞창에 나타나게 합니다.
#
# 2. 인증코드를 입력합니다. 또는 [Ctrl]키를 누른 상태에서 [v]를 한번 누릅니다.
#
# 3. [인증받기] 선택합니다. 자신의 학반과 이름이 나타납니다.
#
# 4. [단말기 등록] 선택합니다.
#
# 5. 등록 되었습니다. 란 메시지가 나타납니다.
#
# 등록을 다 하면 단말기 인증 프로그램은 종료합니다.

# %% [markdown]
# ## 밀리의 서재 사용방법

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 1. 아이톡톡 로그인 상태에서 상단에 있는 주소창 옆에 홈모양(집모양)을 선택하여 경남 이이톡톡 뉴탭 으로 이동
#
# 2. [밀리의 서재 신청] 선택

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# 1. 아래 쪽으로 가서 [신청자 정보 입력] 생년월일 8자리 입력함.
# 2. [확인] 선택
# 3. 신청하기
#
#   다음과 같이 아이디가 생성된다.
#
#   아이디(1학년): 2022571***@gne
#
#   아이디(2학년): 2021571***@gne
#
#   초기암호 : 00000000
#
#   초기암호는 0 이 8 개이다.
#
# 4. [밀리의 서재 앱 다운로드 받기] 선택

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 1. [PC 뷰어] 선택
#
# 2. [Windows] 선택

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# [열기] 선택

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 1. [mille 실행하기(R)] 체크박스 선택 상태로 함.
#
# 2. [마침] 선택

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# [로그인] 선택

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# [기업회원 로그인] 선택

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# 앞에서 신청된 아이디와 비번을 넣어 사용한다.
#
# 아이디(1학년): 2022571***@gne
#
# 아이디(2학년): 2021571***@gne
#
# 초기암호 : 00000000
#
# 초기암호는 0 이 8 개이다.
#
# 처음 로그인 하면 초기암호를 변경하는 것을 한번 더 하게 된다.
